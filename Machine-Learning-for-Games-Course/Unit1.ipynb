# %% [markdown]
# # Unit 1 – Summary
#
# In this unit, you will integrate your first AI model into a Unity game. You’ll learn the basics of **sentence similarity**, the difference between running models **locally vs via API**, and how to use the **Hugging Face Hub**.
#
# Using **Unity Sentis** and **Sharp Transformers**, you will build a demo where a robot understands and executes player commands. This serves as the foundation for more advanced demos, such as stealth or dungeon escape games, and can later be expanded with **speech-to-text input** for voice commands.

# %% [markdown]
# ### **What is Sentence Similarity**
#
# * It is a task that measures how similar a sentence is to a set of target sentences.
# * It works by transforming sentences into **vectors (embeddings)** that capture the meaning.
# * Cosine similarity calculates how close two vectors are:
#
# * 1 → identical
# * 0 → no correlation
#
# ---
#
# ### **Game Pipeline**
#
# 1. Player types an order → e.g., “Can you bring me the red cube?”
# 2. List of robot actions: \[“Hello”, “Happy”, “Bring red box”, “Move to blue pillar”].
# 3. Tokenized input (with **Sharp Transformers**) → converted to numbers.
# 4. Passed to the model (with **Unity Sentis**) → gets text embedding.
# 5. Compare with the available action embeddings → calculate cosine similarity.
# 6. If the **similarity > 0.2** → robot performs the corresponding action.
# 7. If < 0.2 → robot plays the “I’m perplexed” animation (order too different or nonsensical).

# %% [markdown]
# ### **Sentence Similarity**
#
# It's the task of determining how similar two texts are in meaning.
#
# * Models convert the text into **embeddings** (numerical vectors that capture the semantics).
# * They then calculate the closeness between the vectors, often with **cosine similarity**.
#
# ---
#
# ### **Example**
#
# Input: *“Machine learning is so easy.”*
# Comparison:
#
# * “Deep learning is so straightforward.” → **0.623**
# * “This is so difficult, like rocket science.” → **0.413**
# * “I can’t believe how much I struggled with this.” → **0.256**
#
# ---
#
# ### **Use Cases**
#
# * **Information Retrieval**: Search documents for information by comparing queries and sentences.
# * **Clustering/Grouping**: Group similar texts.
#
# ---
#
# ### **Main Tools**
#
# * **Sentence Transformers library** → Powerful for computing embeddings of sentences, paragraphs, or entire documents.
# * **Hugging Face Hub** → Offers thousands of ready-to-use models (via library, widgets, or API endpoints).
#
# ---
#
# ### **Task Variants**
#
# * **Passage Ranking** 📄
# Sorts documents based on relevance to a query (evaluated with *Mean Reciprocal Rank*).
# * **Semantic Textual Similarity (STS)**
# Measures the semantic similarity between two texts (benchmark → *STS Benchmark*).
# Evaluated with *Pearson’s Rank Correlation*.

# %%
# %pip install -U sentence-transformers
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (5.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (4.50.3)
# Requirement already satisfied: tqdm in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (11.1.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sentence-transformers) (4.12.2)
# Requirement already satisfied: filelock in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.12.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: networkx in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tf-keras in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tf-keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (24.2)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (75.8.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.5.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (1.71.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.11.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (2.1.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (3.13.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorflow<2.21,>=2.20->tf-keras) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras) (0.45.1)
# Requirement already satisfied: rich in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (13.9.4)
# Requirement already satisfied: namex in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.7)
# Requirement already satisfied: pillow in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (11.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\dell\anaconda3\envs\ai_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer, util
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\activations_tf.py:22
#      21 try:
# ---> 22     import tf_keras as keras
#      23 except (ModuleNotFoundError, ImportError):
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras import __internal__
#       4 from tf_keras import activations
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.__internal__ import backend
#       4 from tf_keras.__internal__ import layers
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\__internal__\backend\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from tf_keras.src.backend import _initialize_variables as initialize_variables
#       4 from tf_keras.src.backend import track_variable
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\src\__init__.py:21
#      15 """Implementation of the TF-Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 21 from tf_keras.src import applications
#      22 from tf_keras.src import distribute
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\src\applications\__init__.py:18
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from tf_keras.src.applications.convnext import ConvNeXtBase
#      19 from tf_keras.src.applications.convnext import ConvNeXtLarge
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\src\applications\convnext.py:28
#      26 import tensorflow.compat.v2 as tf
# ---> 28 from tf_keras.src import backend
#      29 from tf_keras.src import initializers
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\src\backend.py:34
#      33 from tf_keras.src.distribute import distribute_coordinator_utils as dc
# ---> 34 from tf_keras.src.dtensor import dtensor_api as dtensor
#      35 from tf_keras.src.engine import keras_tensor
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tf_keras\src\dtensor\__init__.py:18
#      15 """Keras' DTensor library."""
# ---> 18 from tensorflow.compat.v2.experimental import dtensor as dtensor_api
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tensorflow\_api\v2\compat\v2\experimental\__init__.py:22
#      21 from tensorflow.python.framework.dtypes import float8_e5m2fnuz # line: 478
# ---> 22 from tensorflow.python.framework.dtypes import int2 # line: 496
#      23 from tensorflow.python.framework.dtypes import int4 # line: 484
#
# ImportError: cannot import name 'int2' from 'tensorflow.python.framework.dtypes' (c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\tensorflow\python\framework\dtypes.py)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\utils\import_utils.py:1976, in _LazyModule._get_module(self, module_name)
#    1975 try:
# -> 1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\modeling_tf_utils.py:38
#      37 from . import DataCollatorWithPadding, DefaultDataCollator
# ---> 38 from .activations_tf import get_tf_activation
#      39 from .configuration_utils import PretrainedConfig
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\activations_tf.py:27
#      26     if parse(keras.__version__).major > 2:
# ---> 27         raise ValueError(
#      28             "Your currently installed version of Keras is Keras 3, but this is not yet supported in "
#      29             "Transformers. Please install the backwards-compatible tf-keras package with "
#      30             "`pip install tf-keras`."
#      31         )
#      34 def _gelu(x):
#
# ValueError: Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\utils\import_utils.py:1976, in _LazyModule._get_module(self, module_name)
#    1975 try:
# -> 1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\integrations\integration_utils.py:36
#      34 import packaging.version
# ---> 36 from .. import PreTrainedModel, TFPreTrainedModel
#      37 from .. import __version__ as version
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\utils\import_utils.py:1964, in _LazyModule.__getattr__(self, name)
#    1963 elif name in self._class_to_module.keys():
# -> 1964     module = self._get_module(self._class_to_module[name])
#    1965     value = getattr(module, name)
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\utils\import_utils.py:1978, in _LazyModule._get_module(self, module_name)
#    1977 except Exception as e:
# -> 1978     raise RuntimeError(
#    1979         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980         f" traceback):\n{e}"
#    1981     ) from e
#
# RuntimeError: Failed to import transformers.modeling_tf_utils because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sentence_transformers import SentenceTransformer, util
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\__init__.py:15
#       8 import warnings
#      10 from sentence_transformers.backend import (
#      11     export_dynamic_quantized_onnx_model,
#      12     export_optimized_onnx_model,
#      13     export_static_quantized_openvino_model,
#      14 )
# ---> 15 from sentence_transformers.cross_encoder import (
#      16     CrossEncoder,
#      17     CrossEncoderModelCardData,
#      18     CrossEncoderTrainer,
#      19     CrossEncoderTrainingArguments,
#      20 )
#      21 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      22 from sentence_transformers.LoggingHandler import LoggingHandler
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\cross_encoder\__init__.py:3
#       1 from __future__ import annotations
# ----> 3 from .CrossEncoder import CrossEncoder
#       4 from .model_card import CrossEncoderModelCardData
#       5 from .trainer import CrossEncoderTrainer
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:29
#      27 from sentence_transformers import __version__
#      28 from sentence_transformers.backend import load_onnx_model, load_openvino_model
# ---> 29 from sentence_transformers.cross_encoder.fit_mixin import FitMixin
#      30 from sentence_transformers.cross_encoder.model_card import CrossEncoderModelCardData, generate_model_card
#      31 from sentence_transformers.cross_encoder.util import (
#      32     cross_encoder_init_args_decorator,
#      33     cross_encoder_predict_rank_args_decorator,
#      34 )
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\cross_encoder\fit_mixin.py:20
#      18 from sentence_transformers.cross_encoder.training_args import CrossEncoderTrainingArguments
#      19 from sentence_transformers.datasets.NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 20 from sentence_transformers.datasets.SentenceLabelDataset import SentenceLabelDataset
#      21 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      22 from sentence_transformers.readers import InputExample
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\datasets\__init__.py:13
#      11 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#      12 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ---> 13 from .ParallelSentencesDataset import ParallelSentencesDataset
#      14 from .SentenceLabelDataset import SentenceLabelDataset
#      15 from .SentencesDataset import SentencesDataset
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:19
#      15 import random
#      17 from torch.utils.data import Dataset
# ---> 19 from sentence_transformers import SentenceTransformer
#      20 from sentence_transformers.readers import InputExample
#      22 logger = logging.getLogger(__name__)
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\SentenceTransformer.py:36
#      33 from transformers.dynamic_module_utils import get_class_from_dynamic_module, get_relative_import_files
#      34 from typing_extensions import deprecated
# ---> 36 from sentence_transformers.model_card import SentenceTransformerModelCardData, generate_model_card
#      37 from sentence_transformers.models import Router
#      38 from sentence_transformers.models.Module import Module
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\sentence_transformers\model_card.py:26
#      24 from tqdm.autonotebook import tqdm
#      25 from transformers import TrainerCallback
# ---> 26 from transformers.integrations import CodeCarbonCallback
#      27 from transformers.modelcard import make_markdown_table
#      28 from transformers.trainer_callback import TrainerControl, TrainerState
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\utils\import_utils.py:1964, in _LazyModule.__getattr__(self, name)
#    1962     value = Placeholder
#    1963 elif name in self._class_to_module.keys():
# -> 1964     module = self._get_module(self._class_to_module[name])
#    1965     value = getattr(module, name)
#    1966 elif name in self._modules:
#
# File c:\Users\DELL\anaconda3\envs\ai_env\lib\site-packages\transformers\utils\import_utils.py:1978, in _LazyModule._get_module(self, module_name)
#    1976     return importlib.import_module("." + module_name, self.__name__)
#    1977 except Exception as e:
# -> 1978     raise RuntimeError(
#    1979         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980         f" traceback):\n{e}"
#    1981     ) from e
#
# RuntimeError: Failed to import transformers.integrations.integration_utils because of the following error (look up to see its traceback):
# Failed to import transformers.modeling_tf_utils because of the following error (look up to see its traceback):
# Your currently installed version of Keras is Keras 3, but this is not yet supported in Transformers. Please install the backwards-compatible tf-keras package with `pip install tf-keras`.

# %% [markdown]
# ### **Mini Glossary**
#
# * **Sentence Similarity**
# A technique that measures how semantically similar two sentences are. It is used to connect the player's input to the robot's possible actions.
#
# * **Embedding**
# Numerical representation of a sentence or word. It is a vector that captures the semantic meaning, allowing sentences to be compared using mathematical methods.
#
# * **Tokenizer**
# A tool that converts a sentence (text) into numbers understandable by the model. It divides the text into units (tokens) that the model can process.
#
# * **Cosine Similarity**
# A mathematical measure that calculates how close two vectors (embeddings) are. The closer the value is to 1, the more similar the sentences are to each other.
#
# * **Threshold**
# Minimum similarity value to decide whether the player's command is valid. In this case: 0.2 → below this threshold, the robot does not recognize the action.
#
# * **Unity Sentis**
# Unity library that allows you to run neural network models directly within the game, without the need for an external server.
#
# * **Sharp Transformers**
# Unity plugin that contains utilities for using Transformer models (e.g., sentence similarity) in games.
